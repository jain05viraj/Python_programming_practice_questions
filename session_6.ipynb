# %%
# Question - 1: how can you unpack a student tuple and produce output that proves each required step was performed?

student = ('Asha', 21, 'BMS')

student_name, student_age, programme = student

print("starting value:", student)
print("Student name :", student_name)
print("Student age:", student_age)
print("programme:", programme)
# Out:
# starting value: ('Asha', 21, 'BMS')
# Student name : Asha
# Student age: 21
# programme: BMS

# %%
# Question - 2: how can you store quotient and remainder in a tuple and produce output that proves each required step was performed?
